# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\SKS I U\Downloads/Nike_Sales_Uncleaned.csv")

# %%
df
# Out:
#       Order_ID Gender_Category Product_Line      Product_Name Size  \
# 0         2000            Kids     Training       SuperRep Go    M
# 1         2001           Women       Soccer     Tiempo Legend    M
# 2         2002           Women       Soccer       Premier III    M
# 3         2003            Kids    Lifestyle        Blazer Mid    L
# 4         2004            Kids      Running    React Infinity   XL
# ...        ...             ...          ...               ...  ...
# 2495      4495            Kids   Basketball     Kyrie Flytrap   XL
# 2496      4496             Men   Basketball     Kyrie Flytrap    L
# 2497      4497             Men       Soccer     Tiempo Legend    7
# 2498      4498           Women     Training  ZoomX Invincible  NaN
# 2499      4499           Women      Running          Air Zoom    M
#
#       Units_Sold      MRP  Discount_Applied  Revenue  Order_Date  \
# 0            NaN      NaN              0.47      0.0  2024-03-09
# ...

# %%
df['Region'].nunique()
# Out:
# 9

# %%
df['Region']
# Out:
# 0       bengaluru
# 1             Hyd
# 2          Mumbai
# 3            Pune
# 4           Delhi
#           ...
# 2495         Pune
# 2496          Hyd
# 2497    Bangalore
# 2498       Mumbai
# 2499       Mumbai
# Name: Region, Length: 2500, dtype: object

# %%
df['Region'].value_counts()
# Out:
# Region
# Delhi        438
# Mumbai       418
# Kolkata      417
# Pune         388
# bengaluru    220
# Bangalore    216
# hyderbad     141
# Hyd          136
# Hyderabad    126
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Order_ID', 'Gender_Category', 'Product_Line', 'Product_Name', 'Size',
#        'Units_Sold', 'MRP', 'Discount_Applied', 'Revenue', 'Order_Date',
#        'Sales_Channel', 'Region', 'Profit'],
#       dtype='object')

# %%
df.shape
# Out:
# (2500, 13)

# %%
df['Units_Sold'].isnull().sum()
# Out:
# np.int64(1235)

# %%
df['Units_Sold'].isnull().sum()
# Out:
# np.int64(1235)

# %%
print("Null:", df['Units_Sold'].isnull().sum())
# Out:
# Null: 1235
# Negative: 205

# %%
df[df['Units_Sold'] >= 0]['Revenue'].sum()
# Out:
# np.float64(744908.2)

# %%
df.groupby('Region')['Revenue'].sum().sort_values(ascending=False).plot(kind='bar')
plt.title('Revenue by City')
plt.show()

# %%
print(df.groupby('Sales_Channel')['Revenue'].sum())
# Out:
# Sales_Channel
# Online    378183.10
# Retail    309001.19
# Name: Revenue, dtype: float64

# %%
df.groupby('Region')['Revenue'].sum().sort_values(ascending=False).plot(kind='bar')
plt.title('Revenue by City - After Cleaning')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.show()
